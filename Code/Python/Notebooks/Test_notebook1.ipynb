# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# this is just text not code

# %%
import math as maths

print(maths.sqrt(16))
# Out:
# 4.0

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

# %%
plt.plot(x, y)
plt.title('y = x^2')
plt.show()
